# %% [markdown]
# ![image.png](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # CNN Exercise
# In this exercise, you will build, train, and evaluate your own Convolutional Neural Network (CNN) using PyTorch.
# We provide the CIFAR10 dataset loading & preprocessing. Your tasks are defined below.

# %%
# Imports
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Loading the CIFAR10 Dataset
# The dataset will be downloaded automatically the first time you run this.
# It consists of 32x32 color images in 10 classes.

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False)
class_names = train_dataset.classes

# %% [markdown]
# ## Visualize Sample Images
# Try to understand the dataset by visualizing some examples.

# %%
dataiter = iter(train_loader)
images, labels = next(dataiter)
fig = plt.figure(figsize=(8, 4))
for idx in range(6):
    plt.subplot(2, 3, idx+1)
    img = images[idx] / 2 + 0.5 # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title(class_names[labels[idx]])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Your Tasks
# 1. Define your own CNN model class in PyTorch.
# 2. Define an appropriate loss function and optimizer.
# 3. Train your model for several epochs.
# 4. Evaluate your model on the test dataset.
# 5. Plot the training loss and test accuracy during training.
#
# Tip: You can refer to earlier examples of CNN implementations, but please try to write your own model.

# %% [markdown]
# ## CNN Model

# %% [markdown]
# ## Define loss function and optimizer

# %% [markdown]
# ## Training

# %% [markdown]
# ## Testing

# %% [markdown]
# ## Plot training loss and test accuracy

# %% [markdown]
# ## Plot results for random samples along with their ground truth
