# %% [markdown]
# ![image.png](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # **Build a Dataset Class for Flower102**
#
# **Label Reference** 📕: https://www.robots.ox.ac.uk/~vgg/data/flowers/102/categories.html

# %%
from torch.utils.data import Dataset
import scipy.io as sio
import numpy as np
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# ### Download the dataset

# %%
# !wget https://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz
# !tar -xvzf /content/102flowers.tgz
# !wget https://www.robots.ox.ac.uk/~vgg/data/flowers/102/imagelabels.mat

# %% [markdown]
# ### Read labels and images names

# %%
labels = sio.loadmat('imagelabels.mat')['labels']
im_names = sio.loadmat('imagelabels.mat')

# %% [markdown]
# ### Dataset Class

# %% [markdown]
# ### Transforms

# %% [markdown]
# ### Create dataset object

# %% [markdown]
# ### Split the data into train and test set

# %% [markdown]
# #### Check dataset size

# %% [markdown]
# ### Create Dataloader objects

# %% [markdown]
# ### Check the dataset shape

# %% [markdown]
# #### Display some images

# %% [markdown]
# # **Build a classifier model using pretrained model**
#
# **Hint: you can use the pretrained ResNet model.**

# %% [markdown]
# ### Load pretrained model and modify the classifier based on the given dataset

# %% [markdown]
# ### Training loop

# %% [markdown]
# ### Validation Loop

# %% [markdown]
# ### Running Training

# %% [markdown]
#  ### Plot loss and accuracy for training and validation

# %% [markdown]
# ### Display sample of predictions

# %% [markdown]
# # **Build a classifier model using CNN model**
#
# ### **Note:**
#
#
# *   Try an optimizer other than Adam
# *   Use Momentum-based optimization
# *   Apply Regularization techniques
# * Apply Batch normalization

# %% [markdown]
# ### Running Training

# %% [markdown]
#  ### Plot loss and accuracy for training and validation

# %% [markdown]
# ### Display sample of predictions
